# %%
f = open("day16-21.txt","r")
txt = f.readlines()
txt
# Out:
# ['...\n']

# %%
hexa = {"0":"0000","1":"0001","2":"0010","3":"0011","4":"0100","5":"0101","6":"0110","7":"0111","8":"1000","9":"1001","A":"1010","B":"1011","C":"1100","D":"1101","E":"1110","F":"1111"}

# %%
string = ""
for i in txt:
    for j in i[:-1]:
        string += hexa[j]
string
# Out:
# '...'

# %%
# def addversions(string,res):
#     after = ""
#     version = string[0:3]
#     res += int(version,2)
#     ID = string[3:6]
#     if int(ID,2) != 4:
#         length = string[6]
#         string = string[7:]
#         if length == "0":
#             length = 15
#             pack = string[:length]
#             pack = int(pack,2)
#             after = string[length+pack:]
#             string = string[length:length+pack]
#             while string:
#                 string,res = addversions(string,res)
#             string += after
#         elif length == "1":
#             length = 11
#             pack = string[:length]
#             pack = int(pack,2)
#             string = string[length:]
#             while pack:
#                 pack -= 1
#                 string,res = addversions(string,res)
#     else:
#         string = string[6:]
#         st = ""
#         while string[0] != "0":
#             st += string[1:5]
#             string = string[5:]
#         st += string[1:5]
#         string = string[5:]
#         st = int(st,2)
#     return string,res
        
# addversions(string,0)[1]

# %%
f = open("day16-21.txt","r")
txt = f.readlines()

string = ""
for i in txt:
    for j in i[:-1]:
        print()
        string += hexa[j]

string
# Out:
# '...'

# %%
def calcval(string,res):
    ID = string[3:6]
    if int(ID,2) == 4:
        string = string[6:]
        st = ""
        while string[0] != "0":
            st += string[1:5]
            string = string[5:]
        st += string[1:5]
        string = string[5:]
        st = int(st,2)
        return string,st
    elif int(ID,2) == 0:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        return string,sum(temp)
    elif int(ID,2) == 1:
        result = 1
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        for x in temp:
            result = x*result
        return string,result
    elif int(ID,2) == 2:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        return string,min(temp)
    elif int(ID,2) == 3:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        return string,max(temp)
    elif int(ID,2) == 5:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        if temp[0] > temp[1]:
            return string,1
        else:
            return string,0
    elif int(ID,2) == 6:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        if temp[0] < temp[1]:
            return string,1
        else:
            return string,0
    elif int(ID,2) == 7:
        temp = []
        length = string[6]
        string = string[7:]
        if length == "0":
            length = 15
            pack = string[:length]
            pack = int(pack,2)
            after = string[length+pack:]
            string = string[length:length+pack]
            while string:
                print(string)
                string,x = calcval(string,res)
                temp.append(x)
            string += after
        elif length == "1":
            length = 11
            pack = string[:length]
            pack = int(pack,2)
            string = string[length:]
            while pack:
                print(string)
                pack -= 1
                string,x = calcval(string,res)
                temp.append(x)
        if temp[0] == temp[1]:
            return string,1
        else:
            return string,0
    return string,res
    
        
calcval(string,[])
# Out:
# ...
# 1111001100011110111111100111101111011001110110100100010101010100000000011010101110000000000000100001010100000100101000100111010001011110000100000000011110100010000111000001110010000110
# 01010100000000011010101110000000000000100001010100000100101000100111010001011110000100000000011110100010000111000001110010000110
# 1110000000000000100001010100000100101000100111010001011110000100000000011110100010000111000001110010000110
# 010100000100101000100111010001011
# 0101000100111010001011
# 11010001011
# 110000100000000011110100010000111000001110010000110
# 110100010000111000001110010000110
# 0111000001110010000110
# 10010000110
# ...
# 01010010101101000001110110010110111110100000110011110110001011100111110100110011101000010101100100101110011011111001101100010
# 10110010110111110100000110011110110001011100111110100110011101000010101100100101110011011111001101100010
# 00110011110110001011100111110100110011101000010101100100101110011011111001101100010
# ...
